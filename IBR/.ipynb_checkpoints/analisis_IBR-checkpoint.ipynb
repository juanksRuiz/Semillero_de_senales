# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("datosIBR.xlsx",decimal=",")

# %%
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3114 entries, 0 to 3113
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Fecha (dd/mm/aaaa)               3114 non-null   datetime64[ns]
#  1   Excepción                        1995 non-null   object
#  2   Plazo real (días calendario)     1995 non-null   float64
#  3   IBR(tasa_efectiva)               3114 non-null   float64
#  4   IBR                              3114 non-null   float64
#  5   BANCO DAVIVIENDA                 2627 non-null   object
#  6   Colpatria Red Multibanca         366 non-null    float64
#  7   BANAGRARIO                       2870 non-null   object
#  8   BANCO OCCIDENTE                  2661 non-null   object
#  9   Helm Bank S.A.                   576 non-null    object
#  10  Banco de Crédito                 401 non-null    float64
# ...

# %%
#df.columns
plt.plot(df['Fecha (dd/mm/aaaa)'],df["IBR"])
plt.xlabel("Fecha")
plt.ylabel("IBR")
plt.title("Evolución del IBR")
# Out:
# Text(0.5, 1.0, 'Evolución del IBR')
